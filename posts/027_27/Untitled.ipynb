# %% [markdown]
# ---
# title: "Why Am I So Dependent on My Phone: M Realization"
# description: "Having a social battery is okay!"
# author: "Athena"
# date: "11/25/2025"
# categories:
#   - LLMs
#   - Learning
# ---
